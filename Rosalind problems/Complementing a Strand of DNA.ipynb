# %%
with open('rosalind_dna.txt') as file:
    lines = file.readlines()
    dna = lines[-1]
    
comp = ''
for l in dna:
    if l == 'A': comp += 'T'
    elif l == 'T': comp += 'A'
    elif l == 'G': comp += 'C'
    elif l == 'C': comp += 'G'
print(comp[::-1])
# Out:
# ...
